50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3904 - acc: 0.8660 - val_loss: 0.5872 - val_acc: 0.8161
# Epoch 31/50
# 390/390 [==============================] - 7s 18ms/step - loss: 0.3981 - acc: 0.8646 - val_loss: 0.5600 - val_acc: 0.8262
# Epoch 32/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3808 - acc: 0.8703 - val_loss: 0.6004 - val_acc: 0.8084
# Epoch 33/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3881 - acc: 0.8688 - val_loss: 0.5584 - val_acc: 0.8213
# Epoch 34/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3833 - acc: 0.8707 - val_loss: 0.5769 - val_acc: 0.8173
# Epoch 35/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3899 - acc: 0.8696 - val_loss: 0.5546 - val_acc: 0.8227
# Epoch 36/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3712 - acc: 0.8750 - val_loss: 0.5850 - val_acc: 0.8211
# Epoch 37/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3638 - acc: 0.8781 - val_loss: 0.5634 - val_acc: 0.8224
# Epoch 38/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3679 - acc: 0.8749 - val_loss: 0.5740 - val_acc: 0.8228
# Epoch 39/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3614 - acc: 0.8794 - val_loss: 0.5708 - val_acc: 0.8294
# Epoch 40/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3605 - acc: 0.8781 - val_loss: 0.5654 - val_acc: 0.8269
# Epoch 41/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3506 - acc: 0.8812 - val_loss: 0.5532 - val_acc: 0.8273
# Epoch 42/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3410 - acc: 0.8853 - val_loss: 0.5724 - val_acc: 0.8261
# Epoch 43/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3457 - acc: 0.8829 - val_loss: 0.5565 - val_acc: 0.8311
# Epoch 44/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3506 - acc: 0.8829 - val_loss: 0.5799 - val_acc: 0.8232
# Epoch 45/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3399 - acc: 0.8856 - val_loss: 0.5514 - val_acc: 0.8309
# Epoch 46/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3424 - acc: 0.8848 - val_loss: 0.5747 - val_acc: 0.8272
# Epoch 47/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3348 - acc: 0.8867 - val_loss: 0.5898 - val_acc: 0.8243
# Epoch 48/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3375 - acc: 0.8866 - val_loss: 0.5884 - val_acc: 0.8225
# Epoch 49/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3312 - acc: 0.8886 - val_loss: 0.5636 - val_acc: 0.8226
# Epoch 50/50
# 390/390 [==============================] - 7s 17ms/step - loss: 0.3286 - acc: 0.8890 - val_loss: 0.5641 - val_acc: 0.8287
# Model took 348.78 seconds to train
# Accuracy on test data is: 82.87

# %%
# Defining my model 0.8261

model_2 = Sequential()

model_2.add(SeparableConv2D(32, kernel_size=(3, 3), depth_multiplier=2,input_shape=(32, 32, 3))) # Output Size: 30,30,32   RF: 3
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dropout(0.1))

model_2.add(SeparableConv2D(64, kernel_size=(3, 3), depth_multiplier=2))  # 28,28,64 RF: 5
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dropout(0.1))

model_2.add(SeparableConv2D(128, kernel_size=(3, 3),  depth_multiplier=2))  # 26,26,128
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dropout(0.1))

model_2.add(SeparableConv2D(256, kernel_size=(3, 3),  depth_multiplier=1))  # 24,24,128
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dropout(0.1))


model_2.add(MaxPooling2D(pool_size=(2, 2))) # 12,12,128

model_2.add(SeparableConv2D(32, kernel_size=(3, 3),  depth_multiplier=1))  # 10,10,32 
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dropout(0.1))


model_2.add(SeparableConv2D(64, kernel_size=(3, 3),  depth_multiplier=1))  # 8,8,64
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dropout(0.1))


model_2.add(SeparableConv2D(128, kernel_size=(3, 3),  depth_multiplier=1))  # 6,6,32 
model_2.add(BatchNormalization())
model_2.add(Activation('relu'))
model_2.add(Dropout(0.1))


model_2.add(MaxPooling2D(pool_size=(2, 2))) # 3,3,



model_2.add(Flatten())
model_2.add(Dense(num_classes, activation='softmax'))

model_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model_2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d_61 (Separab (None, 30, 30, 32)        278
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# activation_69 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 30, 30, 32)        0
# _________________________________________________________________
# separable_conv2d_62 (Separab (None, 28, 28, 64)        4736
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_70 (Activation)   (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# separable_conv2d_63 (Separab (None, 26, 26, 128)       17664
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 26, 26, 128)       512
# _________________________________________________________________
# activation_71 (Activation)   (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 26, 26, 128)       0
# _________________________________________________________________
# separable_conv2d_64 (Separab (None, 24, 24, 256)       34176
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 24, 24, 256)       1024
# _________________________________________________________________
# activation_72 (Activation)   (None, 24, 24, 256)       0
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 24, 24, 256)       0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 12, 12, 256)       0
# _________________________________________________________________
# separable_conv2d_65 (Separab (None, 10, 10, 32)        10528
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 10, 10, 32)        128
# _________________________________________________________________
# activation_73 (Activation)   (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 10, 10, 32)        0
# _________________________________________________________________
# separable_conv2d_66 (Separab (None, 8, 8, 64)          2400
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_74 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# separable_conv2d_67 (Separab (None, 6, 6, 128)         8896
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 6, 6, 128)         512
# _________________________________________________________________
# activation_75 (Activation)   (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1152)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                11530
# =================================================================
# Total params: 93,024
# Trainable params: 91,616
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
# train the model
start = time.time()
# Train the model
model_info = model_2.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels,